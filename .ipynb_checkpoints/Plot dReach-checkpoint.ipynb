# %%
# Read in the JSON
import json

resolution = 10

data = None
x = []
y = []
with open("dReachTempFile_4_0.smt2.json", "r") as smt2_json:
    data = json.loads("".join(smt2_json.readlines()))
    
    # Itterate through each step
    for trace in data["traces"]:
        # The last trace is always None
        if trace is None:
            break
            
        # Itterate through each variable in the step
        for var_in_mode in trace:
            # The _last varaibles aren't important to plot
            if "last" in var_in_mode["key"]:
                continue
            
            values = []
            first = round(var_in_mode["values"][0]["enclosure"][0])
            last = round(var_in_mode["values"][-1]["enclosure"][-1])
            
            diff = last - first
            if diff == 0:
                values = [first for _ in range(10)]
            else:
                inc = 0
                while len(values) < 10:
                    values.append(round(first + inc, 1))
                    inc += diff / 10
                    
            if "x" in var_in_mode["key"]:
                print("Adding {} to X".format(len(values)))
                x.extend(values)
            else:
                print("Adding {} to Y".format(len(values)))
                y.extend(values)
# Out:
# Adding 11 to X
# Adding 11 to Y
# Adding 11 to X
# Adding 11 to Y
# Adding 11 to X
# Adding 11 to Y
# Adding 11 to Y
# Adding 10 to X

# %%
# Out:
# False

# %%
data
# Out:
# {'traces': [[{'key': 'x_0_0',
#     'mode': 2,
#     'step': 0,
#     'values': [{'enclosure': [0, 0.0625], 'time': [0, 0.0625]},
#      {'enclosure': [0.0625, 0.125], 'time': [0.0625, 0.125]},
#      {'enclosure': [0.125, 0.1875], 'time': [0.125, 0.1875]},
#      {'enclosure': [0.1875, 0.25], 'time': [0.1875, 0.25]},
#      {'enclosure': [0.25, 0.3125], 'time': [0.25, 0.3125]},
#      {'enclosure': [0.3125, 0.375], 'time': [0.3125, 0.375]},
#      {'enclosure': [0.375, 0.4375], 'time': [0.375, 0.4375]},
#      {'enclosure': [0.4375, 0.5], 'time': [0.4375, 0.5]},
#      {'enclosure': [0.5, 0.5625], 'time': [0.5, 0.5625]},
#      {'enclosure': [0.5625, 0.625], 'time': [0.5625, 0.625]},
#      {'enclosure': [0.625, 0.6875], 'time': [0.625, 0.6875]},
#      {'enclosure': [0.6875, 0.75], 'time': [0.6875, 0.75]},
#      {'enclosure': [0.75, 0.8125], 'time': [0.75, 0.8125]},
#      {'enclosure': [0.8125, 0.875], 'time': [0.8125, 0.875]},
#      {'enclosure': [0.875, 0.9375], 'time': [0.875, 0.9375]},
#      {'enclosure': [0.9375, 1], 'time': [0.9375, 1]}]},
#    {'key': 'y_0_0',
#     'mode': 2,
#     'step': 0,
#     'values': [{'enclosure': [0, 0.0625], 'time': [0, 0.0625]},
#      {'enclosure': [0.0625, 0.125], 'time': [0.0625, 0.125]},
#      {'enclosure': [0.125, 0.1875], 'time': [0.125, 0.1875]},
#      {'enclosure': [0.1875, 0.25], 'time': [0.1875, 0.25]},
#      {'enclosure': [0.25, 0.3125], 'time': [0.25, 0.3125]},
#      {'enclosure': [0.3125, 0.375], 'time': [0.3125, 0.375]},
#      {'enclosure': [0.375, 0.4375], 'time': [0.375, 0.4375]},
#      {'enclosure': [0.4375, 0.5], 'time': [0.4375, 0.5]},
#      {'enclosure': [0.5, 0.5625], 'time': [0.5, 0.5625]},
#      {'enclosure': [0.5625, 0.625], 'time': [0.5625, 0.625]},
#      {'enclosure': [0.625, 0.6875], 'time': [0.625, 0.6875]},
#      {'enclosure': [0.6875, 0.75], 'time': [0.6875, 0.75]},
#      {'enclosure': [0.75, 0.8125], 'time': [0.75, 0.8125]},
#      {'enclosure': [0.8125, 0.875], 'time': [0.8125, 0.875]},
#      {'enclosure': [0.875, 0.9375], 'time': [0.875, 0.9375]},
#      {'enclosure': [0.9375, 1], 'time': [0.9375, 1]}]},
#    {'key': 'x_last_0_0',
#     'mode': 2,
#     'step': 0,
#     'values': [{'enclosure': [0, 0], 'time': [0, 0]},
#      {'enclosure': [0, 0], 'time': [1, 1]}]},
#    {'key': 'y_last_0_0',
#     'mode': 2,
#     'step': 0,
#     'values': [{'enclosure': [0, 0], 'time': [0, 0]},
#      {'enclosure': [0, 0], 'time': [1, 1]}]}],
#   [{'key': 'x_1_0',
#     'mode': 6,
#     'step': 1,
#     'values': [{'enclosure': [1, 1.0625], 'time': [0, 0.0625]},
#      {'enclosure': [1.0625, 1.125], 'time': [0.0625, 0.125]},
#      {'enclosure': [1.125, 1.1875], 'time': [0.125, 0.1875]},
#      {'enclosure': [1.1875, 1.25], 'time': [0.1875, 0.25]},
#      {'enclosure': [1.25, 1.3125], 'time': [0.25, 0.3125]},
#      {'enclosure': [1.3125, 1.375], 'time': [0.3125, 0.375]},
#      {'enclosure': [1.375, 1.4375], 'time': [0.375, 0.4375]},
#      {'enclosure': [1.4375, 1.5], 'time': [0.4375, 0.5]},
#      {'enclosure': [1.5, 1.5625], 'time': [0.5, 0.5625]},
#      {'enclosure': [1.5625, 1.625], 'time': [0.5625, 0.625]},
#      {'enclosure': [1.625, 1.6875], 'time': [0.625, 0.6875]},
#      {'enclosure': [1.6875, 1.75], 'time': [0.6875, 0.75]},
#      {'enclosure': [1.75, 1.8125], 'time': [0.75, 0.8125]},
#      {'enclosure': [1.8125, 1.875], 'time': [0.8125, 0.875]},
#      {'enclosure': [1.875, 1.9375], 'time': [0.875, 0.9375]},
#      {'enclosure': [1.9375, 2], 'time': [0.9375, 1]}]},
#    {'key': 'y_1_0',
#     'mode': 6,
#     'step': 1,
#     'values': [{'enclosure': [1, 1.0625], 'time': [0, 0.0625]},
#      {'enclosure': [1.0625, 1.125], 'time': [0.0625, 0.125]},
#      {'enclosure': [1.125, 1.1875], 'time': [0.125, 0.1875]},
#      {'enclosure': [1.1875, 1.25], 'time': [0.1875, 0.25]},
#      {'enclosure': [1.25, 1.3125], 'time': [0.25, 0.3125]},
#      {'enclosure': [1.3125, 1.375], 'time': [0.3125, 0.375]},
#      {'enclosure': [1.375, 1.4375], 'time': [0.375, 0.4375]},
#      {'enclosure': [1.4375, 1.5], 'time': [0.4375, 0.5]},
#      {'enclosure': [1.5, 1.5625], 'time': [0.5, 0.5625]},
#      {'enclosure': [1.5625, 1.625], 'time': [0.5625, 0.625]},
#      {'enclosure': [1.625, 1.6875], 'time': [0.625, 0.6875]},
#      {'enclosure': [1.6875, 1.75], 'time': [0.6875, 0.75]},
#      {'enclosure': [1.75, 1.8125], 'time': [0.75, 0.8125]},
#      {'enclosure': [1.8125, 1.875], 'time': [0.8125, 0.875]},
#      {'enclosure': [1.875, 1.9375], 'time': [0.875, 0.9375]},
#      {'enclosure': [1.9375, 2], 'time': [0.9375, 1]}]},
#    {'key': 'x_last_1_0',
#     'mode': 6,
#     'step': 1,
#     'values': [{'enclosure': [1, 1], 'time': [0, 0]},
#      {'enclosure': [1, 1], 'time': [1, 1]}]},
#    {'key': 'y_last_1_0',
#     'mode': 6,
#     'step': 1,
#     'values': [{'enclosure': [1, 1], 'time': [0, 0]},
#      {'enclosure': [1, 1], 'time': [1, 1]}]}],
#   [{'key': 'x_2_0',
#     'mode': 11,
#     'step': 2,
#     'values': [{'enclosure': [2, 2.0625], 'time': [0, 0.0625]},
#      {'enclosure': [2.0625, 2.125], 'time': [0.0625, 0.125]},
#      {'enclosure': [2.125, 2.1875], 'time': [0.125, 0.1875]},
#      {'enclosure': [2.1875, 2.25], 'time': [0.1875, 0.25]},
#      {'enclosure': [2.25, 2.3125], 'time': [0.25, 0.3125]},
#      {'enclosure': [2.3125, 2.375], 'time': [0.3125, 0.375]},
#      {'enclosure': [2.375, 2.4375], 'time': [0.375, 0.4375]},
#      {'enclosure': [2.4375, 2.5], 'time': [0.4375, 0.5]},
#      {'enclosure': [2.5, 2.5625], 'time': [0.5, 0.5625]},
#      {'enclosure': [2.5625, 2.625], 'time': [0.5625, 0.625]},
#      {'enclosure': [2.625, 2.6875], 'time': [0.625, 0.6875]},
#      {'enclosure': [2.6875, 2.75], 'time': [0.6875, 0.75]},
#      {'enclosure': [2.75, 2.8125], 'time': [0.75, 0.8125]},
#      {'enclosure': [2.8125, 2.875], 'time': [0.8125, 0.875]},
#      {'enclosure': [2.875, 2.9375], 'time': [0.875, 0.9375]},
#      {'enclosure': [2.9375, 3], 'time': [0.9375, 1]}]},
#    {'key': 'y_2_0',
#     'mode': 11,
#     'step': 2,
#     'values': [{'enclosure': [1.9375, 2], 'time': [0, 0.0625]},
#      {'enclosure': [1.875, 1.9375], 'time': [0.0625, 0.125]},
#      {'enclosure': [1.8125, 1.875], 'time': [0.125, 0.1875]},
#      {'enclosure': [1.75, 1.8125], 'time': [0.1875, 0.25]},
#      {'enclosure': [1.6875, 1.75], 'time': [0.25, 0.3125]},
#      {'enclosure': [1.625, 1.6875], 'time': [0.3125, 0.375]},
#      {'enclosure': [1.5625, 1.625], 'time': [0.375, 0.4375]},
#      {'enclosure': [1.5, 1.5625], 'time': [0.4375, 0.5]},
#      {'enclosure': [1.4375, 1.5], 'time': [0.5, 0.5625]},
#      {'enclosure': [1.375, 1.4375], 'time': [0.5625, 0.625]},
#      {'enclosure': [1.3125, 1.375], 'time': [0.625, 0.6875]},
#      {'enclosure': [1.25, 1.3125], 'time': [0.6875, 0.75]},
#      {'enclosure': [1.1875, 1.25], 'time': [0.75, 0.8125]},
#      {'enclosure': [1.125, 1.1875], 'time': [0.8125, 0.875]},
#      {'enclosure': [1.0625, 1.125], 'time': [0.875, 0.9375]},
#      {'enclosure': [1, 1.0625], 'time': [0.9375, 1]}]},
#    {'key': 'x_last_2_0',
#     'mode': 11,
#     'step': 2,
#     'values': [{'enclosure': [2, 2], 'time': [0, 0]},
#      {'enclosure': [2, 2], 'time': [1, 1]}]},
#    {'key': 'y_last_2_0',
#     'mode': 11,
#     'step': 2,
#     'values': [{'enclosure': [2, 2], 'time': [0, 0]},
#      {'enclosure': [2, 2], 'time': [1, 1]}]}],
#   [{'key': 'y_3_0',
#     'mode': 16,
#     'step': 3,
#     'values': [{'enclosure': [0.9375, 1], 'time': [0, 0.0625]},
#      {'enclosure': [0.875, 0.9375], 'time': [0.0625, 0.125]},
#      {'enclosure': [0.8125, 0.875], 'time': [0.125, 0.1875]},
#      {'enclosure': [0.75, 0.8125], 'time': [0.1875, 0.25]},
#      {'enclosure': [0.6875, 0.75], 'time': [0.25, 0.3125]},
#      {'enclosure': [0.625, 0.6875], 'time': [0.3125, 0.375]},
#      {'enclosure': [0.5625, 0.625], 'time': [0.375, 0.4375]},
#      {'enclosure': [0.5, 0.5625], 'time': [0.4375, 0.5]},
#      {'enclosure': [0.4375, 0.5], 'time': [0.5, 0.5625]},
#      {'enclosure': [0.375, 0.4375], 'time': [0.5625, 0.625]},
#      {'enclosure': [0.3125, 0.375], 'time': [0.625, 0.6875]},
#      {'enclosure': [0.25, 0.3125], 'time': [0.6875, 0.75]},
#      {'enclosure': [0.1875, 0.25], 'time': [0.75, 0.8125]},
#      {'enclosure': [0.125, 0.1875], 'time': [0.8125, 0.875]},
#      {'enclosure': [0.0625, 0.125], 'time': [0.875, 0.9375]},
#      {'enclosure': [0, 0.0625], 'time': [0.9375, 1]}]},
#    {'key': 'x_3_0',
#     'mode': 16,
#     'step': 3,
#     'values': [{'enclosure': [3, 3], 'time': [0, 0]},
#      {'enclosure': [3, 3], 'time': [1, 1]}]},
#    {'key': 'x_last_3_0',
#     'mode': 16,
#     'step': 3,
#     'values': [{'enclosure': [3, 3], 'time': [0, 0]},
#      {'enclosure': [3, 3], 'time': [1, 1]}]},
#    {'key': 'y_last_3_0',
#     'mode': 16,
#     'step': 3,
#     'values': [{'enclosure': [1, 1], 'time': [0, 0]},
#      {'enclosure': [1, 1], 'time': [1, 1]}]}],
#   None]}
